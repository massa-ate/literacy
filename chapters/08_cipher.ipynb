# %% [markdown]
# [矢吹太朗『Webのしくみ』（サイエンス社, 2020）](https://github.com/taroyabuki/webbook)
#
# 下のアイコンをクリックすれば，この文書に掲載されているコードを，Google Colab上で実行できます．（Googleのアカウントが必要です．）
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/taroyabuki/webbook/blob/master/chapters/08_cipher.ipynb)
#
# # 第8章 暗号

# %% [markdown]
# ## 8.1 事後否認・改ざん・なりすまし・盗聴

# %% [markdown]
# ## 8.2 暗号の基本
#
# ![図8.1 シーザー暗号（「+13」文字ずらす）を使って，アリスがボブにメッセージを送っている様子](https://raw.githubusercontent.com/taroyabuki/webbook/master/chapters/figures/08-1.svg)

# %%
#準備
# !apt-get install -y -qq hxtools > /dev/null

# %%
#暗号化
# !echo "hello" | rot13

# %%
#復号
# !echo "hello" | rot13 | rot13

# %% [markdown]
# ## 8.3 公開鍵暗号

# %% [markdown]
# ### 8.3.1 盗聴への対策
#
# アリスはボブの公開鍵で暗号化し，ボブはボブの秘密鍵で復号します．
#
# ![図8.2 公開鍵暗号を使った暗号化と復号](https://raw.githubusercontent.com/taroyabuki/webbook/master/chapters/figures/08-2.svg)
#
# ファイル|役割
# --|--
# bob-public.pem|ボブの公開鍵
# bob-private.pem|ボブの秘密鍵
# message4bob|ボブへのメッセージ
# message4bob-secret|ボブへの暗号文

# %%
#(1) ボブが公開鍵と秘密鍵を作る．
# !openssl genrsa -out bob-private.pem 2048
# !openssl rsa -in bob-private.pem -pubout -out bob-public.pem
# Out:
# writing RSA key

# %%
#公開鍵を見てみる．
# !cat bob-public.pem
# Out:
# -----BEGIN PUBLIC KEY-----
# MIIBIjANBgkqhkiG9w0BAQEFAAOCAQ8AMIIBCgKCAQEAp5UmZKmRMQgY6nTZsx2H
# FHp9dOwwPum/b5DeRb/XPBBy3QQwBiMUbmYeOvktiHJuSxnW2zGLGQsfrBzGV9r3
# NuTystsCSOLf6QrXRNY7MRF9Nt7rP2kGXldWEgpGXfnyKHlKAs8RQP9KlN4dd/v4
# H1GWY1l+xgu/fRN5gXADdybV+f4EzmpSpBa6XTq0fA5auo7dcZ56Q8uIMG0nh9mb
# H/tlFdmNS5fMjTOAOKg417lwbS1TR5wcmElydff2P7ZKmqOXv9drai2NYnnl3hv8
# dIiMv9GezKV0kdBY0PjPoLSB0ewt7tXVPIz7V+up36kwFa3/Kf0zhmlVCTv9yHcf
# PQIDAQAB
# -----END PUBLIC KEY-----

# %%
#秘密鍵を見てみる（秘密鍵は本来見せたり公開したりしてはいけない）．
# !cat bob-private.pem
# Out:
# -----BEGIN PRIVATE KEY-----
# MIIEvgIBADANBgkqhkiG9w0BAQEFAASCBKgwggSkAgEAAoIBAQCnlSZkqZExCBjq
# 055dugn5c4HXPZzO/rZlwJz+WDUEiSe3zYK0lm4iEJqirXTVwf6zBdr0ZlZZmGIQ
# cJB3MAmmHcIeXQLPiLloKVngz0OBG0WrHJyeUWneD6cQgWkjZBtEn9Sci5AFgBdS
# w4KsSCNX9Irvx5Z1EK5gpGgr
# -----END PRIVATE KEY-----

# %%
#(2) ボブが公開鍵を公開する．

#(3) アリスがボブの公開鍵を手に入れる．

#(4) アリスがボブの公開鍵を使ってメッセージを暗号化し，ボブに送る．

#(4.1) メッセージをファイルに書く．
# !printf "26G3105" > report

#(4.2) ボブの公開鍵を使って暗号文を作る．
# !openssl pkeyutl -encrypt -pubin -inkey yabuki.pem -in report -out report-secret
# !base64 report-secret
# Out:
# Q1l3m4RPj+GVNUVHiobLVqKU18m2idiFlS1nK9MiCDu5JXBY5o3iN3SKDlkLhtQB0jVvFFOgqsUI
# yFAVDWw0V3az93LuQMtVAQsPIu0G6BRc5iqfPQBZnr9DZkENfG1mbYUA+fQOyJn3TjcZ6kk7Kqd0
# TSUkur0EEavy3tRNWs5HLKC0M3g3l9Uh7it08GZhoDcg15CCxda2DzYeESV3j5bG+WZyapUW99sE
# N0w7mE/GGQKdYKG1ylCUrZ2adM0i7gE6Wl/LObcMUVE8GsRPuhBFcW08aIp4ItmONkvQFB7DpmVH
# zTKQzwCGxPeuJMaR8lGonNDnHmu9TnlzBvk6/w==

# %%
#(5) ボブが暗号文を受け取り，秘密鍵を使って復号する．
# !openssl pkeyutl -decrypt -inkey bob-private.pem -in report-secret
# Out:
# ���e���&և

# %% [markdown]
# ### 8.3.2 デジタル署名
#
# アリスはアリスの秘密鍵でデジタル署名を作り，ボブはアリスの公開鍵でデジタル署名を検証します．
#
# ファイル|役割
# --|--
# alice-public.pem|アリスの公開鍵
# alice-private.pem|アリスの秘密鍵
# alice-message|アリスのメッセージ
# alice-message-signature|アリスのデジタル署名

# %% [markdown]
# #### デジタル署名

# %%
#(1) アリスが公開鍵と秘密鍵を作る．
# !openssl genrsa -out alice-private.pem 2048
# !openssl rsa -in alice-private.pem -pubout -out alice-public.pem

# %%
#(2) アリスがメッセージをファイルに書き，アリスが秘密鍵を使ってデジタル署名を作る．
# !printf "HELLO\n" > alice-message
# !openssl dgst -sha256 -sign alice-private.pem -out alice-message-signature alice-message

# %%
#(3) アリスが公開鍵を公開する．

#(4) ボブがアリスの公開鍵，メッセージ，デジタル署名を取得する．

#(5) ボブがアリスの公開鍵を使って，メッセージのデジタル署名を検証する．
# !openssl dgst -sha256 -verify alice-public.pem -signature alice-message-signature alice-message

# %% [markdown]
# ### 8.3.3 デジタル証明書

# %% [markdown]
# ## 8.4 ウェブの安全性

# %% [markdown]
# ### 8.4.1 TLS
